# %%
# Figure 6.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_one/log/output.npz')

d_list = output['d_list']
signal_ratio_list = output['signal_ratio_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]
linestyle_list = [
    'solid', 'solid', 'solid', 'dashed', 'dotted', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid'
]

fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True, sharey=True)

for ax, idxes in zip(axes, [[0,1,2,3], [3,4,5,6], [6,7,8,9, 10]]):
    for risks_list, color, signal_ratio, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [signal_ratio_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, mean_risks_list, color=color, label=f'ratio={signal_ratio}', linestyle=linestyle)
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, mean_risks_list - 2 * ste_risks_list, mean_risks_list + 2 * ste_risks_list, facecolor=fill_color)

        ax.set_xticks(np.arange(0, 10.1, 0.5))
        ax.set_xlim(gamma_list[0], gamma_list[-1])
        ax.set_ylim(0,100)


legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)


legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[2].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width + 0.15, pos1.y0 + pos1.height + 0.05),
)

fig.savefig('two_matrices.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 7.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_two_lstsq/log/output.npz')

d_list = output['d_list']
signal_ratio_list = output['signal_ratio_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]
linestyle_list = [
    'solid', 'solid', 'solid', 'dashed', 'dotted', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid'
]

fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True, sharey=True)

for ax, idxes in zip(axes, [[0,1,2,3], [3,4,5,6], [6,7,8,9, 10]]):
    for risks_list, color, signal_ratio, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [signal_ratio_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, mean_risks_list, color=color, label=f'ratio={signal_ratio}', linestyle=linestyle)
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, mean_risks_list - 2 * ste_risks_list, mean_risks_list + 2 * ste_risks_list, facecolor=fill_color)

        ax.set_xticks(np.arange(0, 10.1, 0.5))
        ax.set_xlim(gamma_list[0], gamma_list[-1])
        ax.set_ylim(0,100)

legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)


legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[2].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width + 0.15, pos1.y0 + pos1.height + 0.05),
)

plt.savefig('two_matrices_reverse_full.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 8.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('three_matrices/log/output.npz')

d_list = output['d_list']
signal_pos_list = output['signal_pos_list']
signal_pos_list = ['1/12', '2/12', '3/12', '4/12', '5/12', '6/12', '7/12']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]
linestyle_list = [
    'solid', 'solid', 'solid', 'dashed', 'dotted', 'dashed', 'solid'
]

fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True, sharey=True)

for ax, idxes in zip(axes, [[0,1,2], [2,3,4], [4,5,6]]):
    for risks_list, color, signal_pos, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [signal_pos_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, mean_risks_list, color=color, label=f'pos={signal_pos}', linestyle=linestyle)
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, mean_risks_list - 2 * ste_risks_list, mean_risks_list + 2 * ste_risks_list, facecolor=fill_color)

        ax.set_xlim(gamma_list[0], gamma_list[-1])
        ax.set_ylim(0,100)

legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)

legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[2].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width + 0.15, pos1.y0 + pos1.height + 0.05),
)

fig.savefig('three_matrices.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 9.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_diminishing_eval/log/output.npz')

d_list = output['d_list']
eval_size_list = output['eval_size_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]

linestyle_list = [
    'solid', 'solid', 'solid', 'solid', 'solid',
]

fig, axes = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
axes = [axes]

for ax, idxes in zip(axes, [[0,1,2,3,4]]):
    for risks_list, color, eval_size, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [eval_size_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, np.log(mean_risks_list), color=color, label=f'eval_size={eval_size}', linestyle=linestyle)
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, np.log(mean_risks_list - 2 * ste_risks_list), np.log(mean_risks_list + 2 * ste_risks_list), facecolor=fill_color)

        ax.set_xlim(gamma_list[0], gamma_list[-1])

legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)

legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[-1].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width, pos1.y0 + pos1.height),
)

plt.savefig('two_matrices_diminishing_eval.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 10.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_diminishing_eval_beyond_one/log/output.npz')

d_list = output['d_list']
eval_size_list = output['eval_size_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]

linestyle_list = [
    'solid', 'solid', 'solid', 'solid', 'solid',
]

fig, axes = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
axes = [axes]

for ax, idxes in zip(axes, [[0,1,2,3,4]]):
    for risks_list, color, eval_size, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [eval_size_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, np.log(mean_risks_list), color=color, label=f'eval_size={eval_size}')
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, np.log(mean_risks_list - 2 * ste_risks_list), np.log(mean_risks_list + 2 * ste_risks_list), facecolor=fill_color)

        ax.set_ylim(-2, 10)
        ax.set_xlim(gamma_list[0], gamma_list[-1])

legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)


legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[-1].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width, pos1.y0 + pos1.height),
)

plt.savefig('two_matrices_diminishing_eval_beyond_one.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 11.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_diminishing_eval_overlap/log/output.npz')

d_list = output['d_list']
eval_size_list = output['eval_size_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]
linestyle_list = [
    'solid', 'solid', 'solid', 'solid', 'solid',
]

fig, axes = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
axes = [axes]

for ax, idxes in zip(axes, [[0,1,2,3,4]]):
    for risks_list, color, eval_size, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [eval_size_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, np.log(mean_risks_list), color=color, label=f'eval_size={eval_size}')
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, np.log(mean_risks_list - 2 * ste_risks_list), np.log(mean_risks_list + 2 * ste_risks_list), facecolor=fill_color)

        ax.set_ylim(-2, 10)
        ax.set_xlim(gamma_list[0], gamma_list[-1])

legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)



legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[-1].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width, pos1.y0 + pos1.height),
)

plt.savefig('two_matrices_diminishing_eval_overlap.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 12.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_diminishing_eval_overlap_beyond_one/log/output.npz')

d_list = output['d_list']
eval_size_list = output['eval_size_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:purple', 'tab:brown', 'black', 'tab:cyan', 'tab:pink', 'tab:olive', 'crimson'
]
linestyle_list = [
    'solid', 'solid', 'solid', 'solid', 'solid',
]

fig, axes = plt.subplots(1, 1, figsize=(10, 8), sharex=True, sharey=True)
axes = [axes]

for ax, idxes in zip(axes, [[0,1,2,3,4]]):
    for risks_list, color, eval_size, linestyle in zip(
            risks_list_over_signal[idxes],
            [color_list[idx] for idx in idxes],
            [eval_size_list[idx] for idx in idxes],
            [linestyle_list[idx] for idx in idxes]
        ):
        mean_risks_list = risks_list.mean(axis=(1,2))
        ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

        ax.plot(gamma_list, np.log(mean_risks_list), color=color, label=f'eval_size={eval_size}')
        fill_color = np.array(colors.to_rgba(color))
        fill_color[3] *= 0.2
        ax.fill_between(gamma_list, np.log(mean_risks_list - 2 * ste_risks_list), np.log(mean_risks_list + 2 * ste_risks_list), facecolor=fill_color)

        ax.set_ylim(-2, 10)
        ax.set_xlim(gamma_list[0], gamma_list[-1])

legend_by_label = {}
for ax_idx, ax in enumerate(axes):
    handles, labels = ax.get_legend_handles_labels()
    for hl_idx, output in enumerate(zip(handles, labels)):
        if ax_idx > 0 and hl_idx == 0:
            continue
        handle, label = output
        legend_by_label.setdefault(label, []).append(handle)



legend_handles = []
legend_labels = []
for label, handles in legend_by_label.items():
    if len(handles) == 1:
        legend_handles.append(handles[0])
    else:
        legend_handles.append(tuple(handles))
    legend_labels.append(label)

pos1 = axes[-1].get_position()

fig.legend(
    legend_handles,
    legend_labels,
    loc='upper right',
    bbox_to_anchor=(pos1.x0 + pos1.width, pos1.y0 + pos1.height),
)

plt.savefig('two_matrices_diminishing_eval_overlap_beyond_one.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 13.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_non_diag/log/output.npz')

d_list = output['d_list']
angle_list = output['angle_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black'
]

for risks_list, color, angle in zip(risks_list_over_signal, color_list, angle_list):
    mean_risks_list = risks_list.mean(axis=(1,2))
    ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

    plt.plot(gamma_list, mean_risks_list, color=color, label=f'angle={angle}')
    fill_color = np.array(colors.to_rgba(color))
    fill_color[3] *= 0.2
    plt.fill_between(gamma_list, mean_risks_list - 2 * ste_risks_list, mean_risks_list + 2 * ste_risks_list, facecolor=fill_color)

plt.legend()
plt.xlim(gamma_list[0], gamma_list[-1])
plt.ylim(0,40)
plt.savefig('two_matrices_non_diag.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 14.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_non_diag_two/log/output.npz')

d_list = output['d_list']
angle_list = output['angle_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black'
]

for risks_list, color, angle in zip(risks_list_over_signal, color_list, angle_list):
    mean_risks_list = risks_list.mean(axis=(1,2))
    ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

    plt.plot(gamma_list, mean_risks_list, color=color, label=f'angle={angle}')
    fill_color = np.array(colors.to_rgba(color))
    fill_color[3] *= 0.2
    plt.fill_between(gamma_list, mean_risks_list - 2 * ste_risks_list, mean_risks_list + 2 * ste_risks_list, facecolor=fill_color)

plt.legend()
plt.xlim(gamma_list[0], gamma_list[-1])
plt.ylim(0,20)
plt.savefig('two_matrices_non_diag_two.pdf', dpi=100, bbox_inches='tight')

# %%
# Figure 15.

import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

output = np.load('two_matrices_non_diag_change_size/log/output.npz')

d_list = output['d_list']
size_list = output['size_list']
group_sizes = output['group_sizes']
risks_list_over_signal = output['risks_list_over_signal']

gamma_list = d_list / np.sum(group_sizes)
color_list = [
    'tab:blue', 'tab:orange', 'tab:red', 'tab:green', 'tab:purple', 'tab:brown', 'black'
]

for risks_list, color, size in zip(risks_list_over_signal, color_list, size_list):
    mean_risks_list = risks_list.mean(axis=(1,2))
    ste_risks_list = risks_list.std(axis=(1,2)) / np.sqrt(risks_list.shape[1])

    plt.plot(gamma_list, mean_risks_list, color=color, label=f'size={size}')
    fill_color = np.array(colors.to_rgba(color))
    fill_color[3] *= 0.2
    plt.fill_between(gamma_list, mean_risks_list - 2 * ste_risks_list, mean_risks_list + 2 * ste_risks_list, facecolor=fill_color)

plt.legend()
plt.xlim(gamma_list[0], gamma_list[-1])
plt.ylim(0,20)
plt.savefig('two_matrices_non_diag_change_size.pdf', dpi=100, bbox_inches='tight')
